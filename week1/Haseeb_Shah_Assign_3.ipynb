# %% [markdown]
# # Week 1 - Day 3 Lab: Data & Matrix Manipulation
# In this lab, you'll work with a realistic weather dataset. You'll use **Pandas** to explore and clean the data, and **NumPy** to perform matrix operations.
#
# **Dataset:** `hourly_weather_10_days.csv` (10 days of hourly weather data)

# %% [markdown]
# ## Step 1: Load the Data
# - Use Pandas to load the CSV file
# - Display the first few rows
# - Check the number of rows and columns

# %%
# TODO: Load the data into a DataFrame
import pandas as pd


# Replace the file path if needed
df = pd.read_csv('C:/Users/hasee/Downloads/hourly_weather_10_days.csv')
print(df.head(10))
print(df.tail(10))
# Out:
#              timestamp  temperature_C  humidity_%  wind_speed_kmph  \
# 0  2023-03-01 00:00:00           16.6        74.4              5.7
# 1  2023-03-01 01:00:00           16.2        78.5              5.0
# 2  2023-03-01 02:00:00           15.3        73.3              4.7
# 3  2023-03-01 03:00:00           15.8        72.4              1.3
# 4  2023-03-01 04:00:00           20.9        70.6              6.8
# 5  2023-03-01 05:00:00           20.8        63.7              NaN
# 6  2023-03-01 06:00:00           22.8        67.0             11.3
# 7  2023-03-01 07:00:00           22.5        63.7             12.3
# 8  2023-03-01 08:00:00           21.2        65.3             13.8
# 9  2023-03-01 09:00:00           28.2        64.5             10.8
#
#    pressure_hPa  visibility_km
# 0        1012.5            9.5
# 1        1012.1           10.3
# 2           NaN           11.1
# 3        1005.0            8.9
# 4        1016.3            9.8
# 5        1017.9           10.8
# 6        1002.3            9.0
# 7        1018.6           10.9
# 8        1017.3           10.7
# 9        1009.6           11.0
#                timestamp  temperature_C  humidity_%  wind_speed_kmph  \
# 230  2023-03-10 14:00:00           24.0        62.5             14.9
# 231  2023-03-10 15:00:00           22.7         NaN             14.9
# 232  2023-03-10 16:00:00           24.2        64.4             12.3
# 233  2023-03-10 17:00:00           22.6        61.8              9.1
# 234  2023-03-10 18:00:00           21.2        68.4             10.5
# 235  2023-03-10 19:00:00           23.4        67.2              9.9
# 236  2023-03-10 20:00:00           20.2         NaN              8.2
# 237  2023-03-10 21:00:00            NaN        71.4              4.5
# 238  2023-03-10 22:00:00           20.9        79.0              5.0
# 239  2023-03-10 23:00:00           11.5         NaN              7.3
#
#      pressure_hPa  visibility_km
# 230        1013.5            9.9
# 231        1007.7            8.7
# 232           NaN            8.4
# 233        1005.7            7.8
# 234        1009.7            8.9
# 235        1016.9            8.2
# 236        1013.7           10.3
# 237        1001.7           10.7
# 238        1017.7            8.9
# 239           NaN           12.5

# %% [markdown]
# ## Step 2: Basic Exploration
# - Check column names and data types
# - Display basic statistics using `.describe()`
# - Count missing values in each column

# %%
# TODO: Explore the DataFrame
print(df.info())
print(df.describe())
print(df.isna().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240 entries, 0 to 239
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   timestamp        240 non-null    object
#  1   temperature_C    228 non-null    float64
#  2   humidity_%       224 non-null    float64
#  3   wind_speed_kmph  226 non-null    float64
#  4   pressure_hPa     223 non-null    float64
#  5   visibility_km    228 non-null    float64
# dtypes: float64(5), object(1)
# memory usage: 11.4+ KB
# None
#        temperature_C  humidity_%  wind_speed_kmph  pressure_hPa  visibility_km
# count     228.000000  224.000000       226.000000    223.000000     228.000000
# mean       21.315789   66.795982        10.105310   1011.884753       9.989474
# std         3.421237    8.190300         3.940668      5.187080       1.022166
# min        11.500000   47.800000         1.300000    998.100000       6.800000
# 25%        18.700000   61.075000         6.625000   1008.900000       9.275000
# 50%        21.900000   66.300000         9.800000   1012.100000      10.000000
# 75%        23.925000   72.725000        13.500000   1015.100000      10.700000
# max        28.700000   88.100000        17.800000   1027.000000      12.600000
# timestamp           0
# temperature_C      12
# humidity_%         16
# wind_speed_kmph    14
# pressure_hPa       17
# visibility_km      12
# dtype: int64

# %% [markdown]
# ## Step 3: Handle Missing Values
# - Drop or fill missing values
# - Justify your approach (e.g., fill with mean, forward fill, etc.)

# %%
# TODO: Fill missing values
# Example: df['column'] = df['column'].fillna(df['column'].mean())

# Fill in your logic here
df['temperature_C']= df['temperature_C'].fillna(df['temperature_C'].mean())
df['wind_speed_kmph']= df['wind_speed_kmph'].fillna(df['wind_speed_kmph'].mean())
#df=df.dropna(subset=['visibility_km'])
#df=df.dropna(subset=['pressure_hPa'])

print(df['temperature_C'])
print(df['wind_speed_kmph'])
print(df['visibility_km'])
print(df['pressure_hPa'])

print("Ab dekho in columns ma hamari koi missing values nhi han or model training ky time most accurate predictions kryga ")

print(df['temperature_C'].isna().sum())
print(df['wind_speed_kmph'].isna().sum())
print(df['temperature_C'].isna().sum())
print(df['pressure_hPa'].isna().sum())
# Out:
# 0      16.600000
# 1      16.200000
# 2      15.300000
# 3      15.800000
# 4      20.900000
#          ...
# 235    23.400000
# 236    20.200000
# 237    21.315789
# 238    20.900000
# 239    11.500000
# Name: temperature_C, Length: 240, dtype: float64
# 0      5.7
# 1      5.0
# 2      4.7
# 3      1.3
# 4      6.8
#       ...
# 235    9.9
# 236    8.2
# 237    4.5
# 238    5.0
# 239    7.3
# Name: wind_speed_kmph, Length: 240, dtype: float64
# 0       9.5
# 1      10.3
# 2      11.1
# 3       8.9
# 4       9.8
#        ...
# 235     8.2
# 236    10.3
# 237    10.7
# 238     8.9
# 239    12.5
# Name: visibility_km, Length: 240, dtype: float64
# 0      1012.5
# 1      1012.1
# 2         NaN
# 3      1005.0
# 4      1016.3
#         ...
# 235    1016.9
# 236    1013.7
# 237    1001.7
# 238    1017.7
# 239       NaN
# Name: pressure_hPa, Length: 240, dtype: float64
# Ab dekho in columns ma hamari koi missing values nhi han or model training ky time most accurate predictions kryga
# 0
# 0
# 0
# 17

# %% [markdown]
# ## Step 4: Data Analysis
# - Calculate daily average temperature
# - Find max, min, mean for each metric
# - Which hour of the day is the most humid on average?

# %%
# TODO: Perform analysis
# Use groupby, aggregation, and filtering functions
df['timestamp'] = pd.to_datetime(df['timestamp'])
df['date']= df['timestamp'].dt.date
print(df.groupby('date')['temperature_C'].mean())
print("This is the average temperature per day")
print("\n")


df['hour']= df['timestamp'].dt.hour
avghum=df.groupby('hour')['humidity_%'].mean()
a=avghum.idxmax()
print(a)
print(avghum.max())
print("This is the maximum hour at which humidity is maximum")
# Out:
# date
# 2023-03-01    21.263158
# 2023-03-02    21.258991
# 2023-03-03    21.304825
# 2023-03-04    21.425658
# 2023-03-05    21.529825
# 2023-03-06    21.858333
# 2023-03-07    21.179825
# 2023-03-08    20.947807
# 2023-03-09    20.792325
# 2023-03-10    21.597149
# Name: temperature_C, dtype: float64
# This is the average temperature per day
#
#
# 23
# 79.1
# This is the maximum hour at which humidity is maximum

# %%
print(df.groupby('temperature_C')['humidity_%'].mean())
print(df.groupby('temperature_C')['wind_speed_kmph'].mean())
print(df.groupby('temperature_C')['visibility_km'].mean())
print("\n")


print("Average windspeed:  ",df['wind_speed_kmph'].mean())
print("Average temperature:  ",df['temperature_C'].mean())
print("Minimum temperature:  ",df['temperature_C'].min())
print("Maximum visibility:  ",df['visibility_km'].max())

print("Done from statics")
stats=df.describe().loc[['min', 'max', 'mean']]
print(stats)
print("\n")

# Placeholder example:
df['hour'] = df['timestamp'].dt.hour
avg_humidity_by_hour = df.groupby('hour')['humidity_%'].mean()
print(df['hour'])
print(avg_humidity_by_hour)
print("\n")
print(df[df['wind_speed_kmph'] > 5]['wind_speed_kmph'])
# Out:
# temperature_C
# 11.5     NaN
# 12.4    76.6
# 13.5    76.1
# 13.6    78.7
# 14.3    83.8
#         ...
# 27.1    65.0
# 27.6    60.5
# 28.2    64.5
# 28.5    54.0
# 28.7    63.4
# Name: humidity_%, Length: 106, dtype: float64
# temperature_C
# 11.5     7.30
# 12.4     5.00
# 13.5     6.20
# 13.6     6.70
# 14.3     6.30
#         ...
# 27.1    13.75
# 27.6    12.80
# 28.2    10.80
# 28.5    11.50
# 28.7    13.40
# Name: wind_speed_kmph, Length: 106, dtype: float64
# temperature_C
# 11.5    12.50
# 12.4    11.60
# 13.5     8.50
# 13.6    10.80
# 14.3     8.30
#         ...
# 27.1    10.35
# 27.6    10.70
# 28.2    11.00
# 28.5    10.90
# 28.7    10.10
# Name: visibility_km, Length: 106, dtype: float64
#
#
# Average windspeed:   10.105309734513273
# Average temperature:   21.31578947368421
# Minimum temperature:   11.5
# Maximum visibility:   12.6
# Done from statics
#                 timestamp  temperature_C  humidity_%  wind_speed_kmph  \
# min   2023-03-01 00:00:00      11.500000   47.800000          1.30000
# max   2023-03-10 23:00:00      28.700000   88.100000         17.80000
# mean  2023-03-05 23:30:00      21.315789   66.795982         10.10531
#
#       pressure_hPa  visibility_km  hour
# min     998.100000       6.800000   0.0
# max    1027.000000      12.600000  23.0
# mean   1011.884753       9.989474  11.5
#
#
# 0       0
# 1       1
# 2       2
# 3       3
# 4       4
#        ..
# 235    19
# 236    20
# 237    21
# 238    22
# 239    23
# Name: hour, Length: 240, dtype: int32
# hour
# 0     78.170000
# 1     78.420000
# 2     75.414286
# 3     71.940000
# 4     69.310000
# 5     68.611111
# 6     65.770000
# 7     65.044444
# 8     63.490000
# 9     59.650000
# 10    58.710000
# 11    58.910000
# 12    59.422222
# 13    58.330000
# 14    61.366667
# 15    60.888889
# 16    59.600000
# 17    64.030000
# 18    66.971429
# 19    69.190000
# 20    67.488889
# 21    72.700000
# 22    73.750000
# 23    79.100000
# Name: humidity_%, dtype: float64
#
#
# 0       5.70000
# 4       6.80000
# 5      10.10531
# 6      11.30000
# 7      12.30000
#          ...
# 233     9.10000
# 234    10.50000
# 235     9.90000
# 236     8.20000
# 239     7.30000
# Name: wind_speed_kmph, Length: 216, dtype: float64

# %%
#it means ky har ghanty ky hisab sy ye humidity analyze krha ha 
#date ka format islie change kia qky pahly python usy string smjh rha tha ab dataframe ma ye clear ha ky date format ha iska

# %% [markdown]
# ## Step 5: NumPy Matrix Exercises
# Convert relevant DataFrame columns into NumPy arrays and perform matrix operations.

# %%
# TODO: Extract temperature and wind_speed as NumPy arrays
import numpy as np

temp = df['temperature_C'].to_numpy()
wind = df['wind_speed_kmph'].to_numpy()

# %% [markdown]
# ### a) Reshape into matrix form
# - Assume each row is a day
# - Reshape temperature into a (10, 24) matrix
# - Calculate daily min, max, and mean using axis-based operations

# %%
# TODO: Reshape and aggregate
temp_matrix = temp.reshape((10, 24))
print("Maximum", temp_matrix.max(axis=1) )
print("Minimum", temp_matrix.min(axis=1) )
print("Average", temp_matrix.mean(axis=1))

# Write functions to find min, max, mean across rows
# Out:
# Maximum [28.2 28.7 25.7 27.1 24.9 26.2 25.9 26.  27.1 28.5]
# Minimum [14.7 15.7 13.6 15.9 12.4 15.5 15.3 13.5 14.3 11.5]
# Average [21.26315789 21.25899123 21.30482456 21.42565789 21.52982456 21.85833333
#  21.17982456 20.94780702 20.79232456 21.59714912]

# %% [markdown]
# ### b) Normalize the temperature matrix
# - Subtract the mean and divide by std deviation
# - Do it manually using NumPy functions

# %%
# TODO: Normalize temp_matrix
# Placeholder for function: def normalize(matrix):
# return ...
def normalize(abc):
    mean= np.mean(abc)

    std=np.std(abc)

    return (abc - mean ) / std

print(normalize(temp_matrix))

# Apply it to temp_matrix
# Out:
# [[-1.41730720e+00 -1.53752522e+00 -1.80801577e+00 -1.65774325e+00
#   -1.24963470e-01 -1.55017975e-01  4.46072133e-01  3.55908617e-01
#   -3.47999536e-02  2.06901543e+00 -4.44089210e-16  1.28759828e+00
#    1.22748927e+00  6.26399166e-01  1.88868839e+00  7.46617187e-01
#    2.05636090e-01  7.16562682e-01  5.36235649e-01  2.35690595e-01
#   -9.36435116e-01 -5.75781051e-01 -4.85617535e-01 -1.98834281e+00]
#  [-1.62768874e+00 -1.68779775e+00 -1.11676215e+00 -3.95454019e-01
#    2.05636090e-01 -3.47999536e-02  4.16017628e-01  5.53635626e-02
#    6.86508176e-01  2.21928795e+00 -2.45181492e-01  1.13732576e+00
#    2.35690595e-01  9.56998725e-01  3.85963122e-01  1.75581584e-01
#    7.76671693e-01 -4.44089210e-16  8.66835209e-01  2.05636090e-01
#   -4.25508524e-01 -7.56108084e-01 -1.44736171e+00 -9.96544127e-01]
#  [-2.31894237e+00 -1.68779775e+00 -8.46271600e-01 -1.62768874e+00
#    1.31765279e+00 -1.24963470e-01 -1.55017975e-01 -1.85072481e-01
#    2.95799606e-01  1.31765279e+00  1.04716224e+00 -3.47999536e-02
#    1.25754378e+00  1.75581584e-01  3.25854111e-01  1.01710774e+00
#    9.26944220e-01 -4.44089210e-16  5.96344660e-01  9.26944220e-01
#    4.16017628e-01 -1.24963470e-01 -8.16217095e-01 -1.77796127e+00]
#  [-1.38725270e+00 -7.86162589e-01 -1.02659863e+00 -1.59763424e+00
#    5.53635626e-02  2.35690595e-01  1.73841587e+00  7.16562682e-01
#    1.75581584e-01  8.66835209e-01  1.64825235e+00  9.26944220e-01
#   -4.44089210e-16  1.31765279e+00  8.06726198e-01 -5.45726546e-01
#    5.06181144e-01  7.16562682e-01 -4.55563030e-01 -6.48544591e-02
#   -7.86162589e-01 -1.55017975e-01 -4.85617535e-01 -1.62768874e+00]
#  [-4.85617535e-01 -2.67959643e+00 -7.86162589e-01 -7.26053578e-01
#   -3.47999536e-02 -9.49089645e-02 -5.15672040e-01 -2.45181492e-01
#    1.01710774e+00 -4.44089210e-16  5.96344660e-01  5.36235649e-01
#    4.46072133e-01  9.56998725e-01  1.07721675e+00  1.01710774e+00
#    8.36780704e-01  3.55908617e-01  8.66835209e-01  5.96344660e-01
#    2.65745101e-01  7.76671693e-01 -1.35719819e+00 -8.76326105e-01]
#  [-1.05665314e+00 -8.46271600e-01 -6.48544591e-02  1.75581584e-01
#   -1.02659863e+00 -1.41730720e+00  5.96344660e-01  1.04716224e+00
#    3.55908617e-01  1.40781631e+00  1.22748927e+00  8.96889714e-01
#    1.46792532e+00 -1.55017975e-01 -4.74544822e-03  4.16017628e-01
#    1.01710774e+00  6.56453671e-01  1.28759828e+00  5.66290155e-01
#    7.76671693e-01 -1.74790676e+00 -4.55563030e-01 -1.20692567e+00]
#  [-1.65774325e+00 -1.11676215e+00 -1.02659863e+00 -4.44089210e-16
#   -4.55563030e-01  6.26399166e-01 -4.25508524e-01  1.31765279e+00
#    5.36235649e-01  1.37776180e+00  9.26944220e-01  3.55908617e-01
#    1.04716224e+00  9.56998725e-01  8.66835209e-01  4.76126638e-01
#   -3.95454019e-01 -1.85072481e-01 -2.45181492e-01  1.75581584e-01
#    5.66290155e-01 -1.77796127e+00 -1.80801577e+00 -1.11676215e+00]
#  [-2.34899687e+00 -4.44089210e-16 -1.17687116e+00 -1.95828830e+00
#   -3.47999536e-02 -8.46271600e-01  8.54180680e-02  6.26399166e-01
#    1.40781631e+00  2.95799606e-01 -4.44089210e-16  1.07721675e+00
#    7.16562682e-01 -4.44089210e-16  9.87053231e-01  6.86508176e-01
#    1.25754378e+00  9.26944220e-01  3.55908617e-01  5.53635626e-02
#   -6.95999073e-01 -1.20692567e+00 -1.83807028e+00 -1.02659863e+00]
#  [-2.10856083e+00 -1.20692567e+00 -1.71785226e+00  5.53635626e-02
#   -1.05665314e+00 -3.47999536e-02 -2.15126986e-01 -4.74544822e-03
#    4.46072133e-01 -3.47999536e-02  1.13732576e+00  1.31765279e+00
#    1.73841587e+00  1.10727125e+00 -4.44089210e-16  7.16562682e-01
#    5.53635626e-02  8.96889714e-01  6.86508176e-01 -8.16217095e-01
#   -5.15672040e-01 -1.98834281e+00 -6.95999073e-01 -1.53752522e+00]
#  [-1.08670764e+00 -1.50747072e+00 -1.35719819e+00 -1.20692567e+00
#   -3.95454019e-01  1.45527079e-01  5.96344660e-01  9.26944220e-01
#    8.36780704e-01  2.15917894e+00  1.34770730e+00  1.19743477e+00
#   -4.44089210e-16  7.16562682e-01  8.06726198e-01  4.16017628e-01
#    8.66835209e-01  3.85963122e-01 -3.47999536e-02  6.26399166e-01
#   -3.35345008e-01 -4.44089210e-16 -1.24963470e-01 -2.95008698e+00]]

# %% [markdown]
# ### c) Apply custom mask/filter
# - Create a mask for wind speed > 15 kmph
# - Use it to extract high-wind readings

# %%
# TODO: Create boolean mask and filter wind speeds
mask = wind > 15
high_wind = wind[mask]
print(high_wind)
# Out:
# [17.6 16.  16.5 16.3 16.7 15.8 17.8 15.1 16.3 15.2 17.  15.9 15.6 15.8
#  15.4 15.6 16.3 15.3 16.2 16.9 15.3 15.2 15.5 17.4 17.4 15.4 15.4 16.5
#  17.  15.7]

# %% [markdown]
# ## Final Challenge: Write Your Own Function
# Write a function `daily_summary(matrix)` that takes a NumPy matrix of shape (10, 24) and returns a summary dictionary for each day.

# %%
type(temp_matrix)
# Out:
# numpy.ndarray

# %%
def daily_summary(matrix):
    summary = []

    for i, row in enumerate(matrix):
        summary.append({
            "day": i + 1,
            "min": float(np.min(row)),
            "max": float(np.max(row)),
            "mean": float(np.mean(row))
        })

    return summary
x=daily_summary(temp_matrix)
for i in x:
    print(i)
# Out:
# {'day': 1, 'min': -1.988342805934924, 'max': 2.0690154257461266, 'mean': -0.015818160747294068}
# {'day': 2, 'min': -1.6877977517363276, 'max': 2.219287952845425, 'mean': -0.017070431806454883}
# {'day': 3, 'min': -2.31894236555338, 'max': 1.3176527902496358, 'mean': -0.003295450155686025}
# {'day': 4, 'min': -1.627688740896608, 'max': 1.7384158661276714, 'mean': 0.03302041055997782}
# {'day': 5, 'min': -2.6795964305916953, 'max': 1.0772167468907585, 'mean': 0.06432718703899824}
# {'day': 6, 'min': -1.7479067625760467, 'max': 1.467925317348934, 'mean': 0.16305887370336183}
# {'day': 7, 'min': -1.8080157734157658, 'max': 1.3777618010893549, 'mean': -0.040863581930510505}
# {'day': 8, 'min': -2.3489968709732394, 'max': 1.407816306509215, 'mean': -0.11059530722483395}
# {'day': 9, 'min': -2.108560827614362, 'max': 1.7384158661276714, 'mean': -0.15732479043246644}
# {'day': 10, 'min': -2.950086979370432, 'max': 2.1591789420057057, 'mean': 0.08456125099491252}

# %% [markdown]
# ## ✅ Submit your notebook once complete.
# - Add comments where necessary
